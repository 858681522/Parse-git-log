# %% [markdown]
# ### import filesnames and logfiles

# %%
import json
import pandas as pd
import csv

# %%
logfiles=pd.read_csv("../data/talon-twitter-holo_logfiles.csv", sep=',',error_bad_lines=False)
filenames = pd.read_json("../data/talon-twitter-holo_files.txt", orient='records')

# %% [markdown]
# ### concatenate two log files

# %%
logfiles['filenames']=filenames['files']

# %%
logfiles.columns= ['commit','author','date','message','files_changed','lines_inserted','lines_deleted','filenames']

# %%
logfiles
# Out:
#       commit              author        date  \
# 0    f1ca916      "Luke Klinker"  1530723223
# 1    da050cb      "Luke Klinker"  1528992540
# 2    e7b9dc7      "Luke Klinker"  1520880295
# 3    2e7158b      "Luke Klinker"  1518613587
# 4    9e5ff49      "Luke Klinker"  1518374371
# ..       ...                 ...         ...
# 498  d58e24b   "Frieder Bluemle"  1414126059
# 499  1450862      "Luke Klinker"  1414107848
# 500  8334eb0      "Luke Klinker"  1414033667
# 501  3527cbf      "Luke Klinker"  1414008460
# 502  c98669c      "Luke Klinker"  1414008437
#
#                                                message files_changed  \
# 0     "fix-login-issue                             ...            3
# 1     "Add-deprecation-notice-in-favor-of-material-...            1
# 2     "update-strings                              ...            7
# 3     "update-translations                         ...            6
# 4     "Merge-pull-request-44-from-rgarza-compat_wit...
# ...

# %% [markdown]
# ### save csv files

# %%
#logfiles.to_csv(results_path, index = False)
